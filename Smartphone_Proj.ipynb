# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("smartphone.csv")
df
# Out:
#                                 model    price  rating  \
# 0                       OnePlus 11 5G  ₹54,999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2               Samsung Galaxy A14 5G  ₹16,499    75.0
# 3                Motorola Moto G62 5G  ₹14,999    81.0
# 4                  Realme 10 Pro Plus  ₹24,999    82.0
# ...                               ...      ...     ...
# 1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016                      Honor X8 5G  ₹14,990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# Step 1 :- Filter the data or remove the data has price less than 5000 
# Remove the { ₹ and , } from price
df["price"] = df["price"].str.replace("₹","")
df["price"] = df["price"].str.replace(",","")

# %%
# Chanhge the data type of price column

df["price"]=df["price"].astype(int)

# %%
df
# Out:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df = df[df["price"]>4000]
df
# Out:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
#  Processor column which contain Processor

df[df["processor"].str.contains("Processor")]
# Out:
#                                 model  price  rating  \
# 0                       OnePlus 11 5G  54999    89.0
# 1           OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2               Samsung Galaxy A14 5G  16499    75.0
# 3                Motorola Moto G62 5G  14999    81.0
# 4                  Realme 10 Pro Plus  24999    82.0
# ...                               ...    ...     ...
# 1015       Motorola Moto Edge S30 Pro  34990    83.0
# 1016                      Honor X8 5G  14990    75.0
# 1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1018             Motorola Moto G91 5G  19990    80.0
# 1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#      index                            model  price  rating  \
# 0        0                    OnePlus 11 5G  54999    89.0
# 1        1        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        2            Samsung Galaxy A14 5G  16499    75.0
# 3        3             Motorola Moto G62 5G  14999    81.0
# 4        4               Realme 10 Pro Plus  24999    82.0
# ..     ...                              ...    ...     ...
# 979   1015       Motorola Moto Edge S30 Pro  34990    83.0
# 980   1016                      Honor X8 5G  14990    75.0
# 981   1017  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 982   1018             Motorola Moto G91 5G  19990    80.0
# 983   1019           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                    sim  \
# 0              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df["index"]=df["index"]+2

# %%
df
# Out:
#      index                            model  price  rating  \
# 0        2                    OnePlus 11 5G  54999    89.0
# 1        3        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2        4            Samsung Galaxy A14 5G  16499    75.0
# 3        5             Motorola Moto G62 5G  14999    81.0
# 4        6               Realme 10 Pro Plus  24999    82.0
# ..     ...                              ...    ...     ...
# 979   1017       Motorola Moto Edge S30 Pro  34990    83.0
# 980   1018                      Honor X8 5G  14990    75.0
# 981   1019  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 982   1020             Motorola Moto G91 5G  19990    80.0
# 983   1021           Samsung Galaxy M52s 5G  24990    74.0
#
#                                                    sim  \
# 0              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# Defective rows Data , given row no having error inits column

processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))
ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))
display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))
camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))

# %%
df1 = df.copy()

# %%
# Give those row has any error in any column

df1[df1["index"].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#      index                                     model   price  rating  \
# 98     100                            Vivo X Fold 5G  106990     NaN
# 111    113                           Apple iPhone 12   51999    74.0
# 149    151                      Apple iPhone 12 Mini   40999    74.0
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 306    309                   Apple iPhone 12 (128GB)   55999    75.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 362    365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 364    367                          OPPO Find N Flip   89990    88.0
# ...

# %%
df1[df1["card"].str.contains("Android")]
# Out:
#      index                        model  price  rating  \
# 8       10              Nothing Phone 1  26749    85.0
# 9       11           OnePlus Nord 2T 5G  28999    84.0
# 12      14  Xiaomi Redmi Note 12 Pro 5G  24762    79.0
# 17      19         OPPO Reno 9 Pro Plus  45999    86.0
# 18      20               OnePlus 10R 5G  32999    86.0
# ..     ...                          ...    ...     ...
# 973   1011                Xiaomi Civi 3  32990    86.0
# 975   1013                 Oppo Find X6  69990    89.0
# 976   1014                    itel A23s   4787     NaN
# 977   1015           Google Pixel 8 Pro  70990    80.0
# 979   1017   Motorola Moto Edge S30 Pro  34990    83.0
#
#                                                    sim  \
# 8              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 9              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 12      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 17             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# Gives those row which contain error in entire column

df1[df1["index"].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#      index                   model  price  rating                      sim  \
# 631    647         Nokia 2760 Flip   5490     NaN  Dual Sim, 3G, 4G, Wi-Fi
# 855    884  Nokia 5710 XpressAudio   4799     NaN         Dual Sim, 3G, 4G
#
#             processor                               ram  \
# 631  1450 mAh Battery  3.6 inches, 240 x 320 px Display
# 855           No Wifi                       Unisoc T107
#
#                            battery                            display  \
# 631  5 MP Rear & 5 MP Front Camera  Memory Card Supported, upto 32 GB
# 855      48 MB RAM, 128 MB inbuilt                   1450 mAh Battery
#
#                                camera                card  \
# 631                        Kaios v3.0           Bluetooth
# 855  2.4 inches, 240 x 320 px Display  0.3 MP Rear Camera
#
#                                     os
# 631                                NaN
# 855  Memory Card Supported, upto 32 GB

# %%
# Here 631 and 884 has error in whole row , so delet it permanently

df.drop([631,855],inplace=True)

# %%
# processor_rows = set((642,647,649,659,667,701,750,759,819,859,883,884,919,927,929,932,1002))

df1[df1["index"].isin(processor_rows)]
# Out:
#      index                   model  price  rating                        sim  \
# 631    647         Nokia 2760 Flip   5490     NaN    Dual Sim, 3G, 4G, Wi-Fi
# 832    859             LG Folder 2  11999     NaN  Single Sim, 3G, 4G, Wi-Fi
# 855    884  Nokia 5710 XpressAudio   4799     NaN           Dual Sim, 3G, 4G
#
#                   processor                               ram  \
# 631        1450 mAh Battery  3.6 inches, 240 x 320 px Display
# 832  1 GB RAM, 8 GB inbuilt                  1470 mAh Battery
# 855                 No Wifi                       Unisoc T107
#
#                               battery                            display  \
# 631     5 MP Rear & 5 MP Front Camera  Memory Card Supported, upto 32 GB
# 832  2.8 inches, 240 x 320 px Display                   2 MP Rear Camera
# 855         48 MB RAM, 128 MB inbuilt                   1450 mAh Battery
#
#                                camera                card  \
# ...

# %%
# drop the row have processor column error

df1 = df1.drop([631,832,855])

# %%
# ram_rows = set((441,485,534,553,584,610,613,642,647,649,659,667,701,750,759,819,859,884,919,927,929,932,990,1002))
# These all are android , not need to delet
df1[df1["index"].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 437    441            Apple iPhone SE 3 2022   43900     NaN
# 479    485  Huawei Mate 50 RS Porsche Design  239999    81.0
#
#                                                  sim  \
# 437          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 479  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
#
#                                             processor             ram  \
# 437        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 479  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
#
#                                      battery  \
# 437        4.7 inches, 750 x 1334 px Display
# 479  4700 mAh Battery with 66W Fast Charging
#
#                                          display  \
# 437               12 MP Rear & 7 MP Front Camera
# 479  6.74 inches, 1212 x 2616 px, 120 Hz Display
#
#                                                 camera  \
# ...

# %%
# battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,
# 750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))

df1[df1["index"].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 306    309       Apple iPhone 12 (128GB)   55999    75.0
# 362    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 375    378               Nokia 2660 Flip    4649     NaN
# 437    441        Apple iPhone SE 3 2022   43900     NaN
# 446    450           Apple iPhone 15 Pro  130990    75.0
# 615    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 734    756    Apple iPod Touch (7th Gen)   18900     NaN
# 741    764             Apple iPhone SE 4   49990    60.0
# 828    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 885    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 886    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# First of all ya index aya kaha se # battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,
# 759,764,819,855,859,884,915,916,927,929,932,990,1002))

# After checking the "battery" in battery column ,so problem h us row m
# Example
dx = pd.read_csv("smartphone.csv")
dx.reset_index()
# Out:
#       index                            model    price  rating  \
# 0         0                    OnePlus 11 5G  ₹54,999    89.0
# 1         1        OnePlus Nord CE 2 Lite 5G  ₹19,989    81.0
# 2         2            Samsung Galaxy A14 5G  ₹16,499    75.0
# 3         3             Motorola Moto G62 5G  ₹14,999    81.0
# 4         4               Realme 10 Pro Plus  ₹24,999    82.0
# ...     ...                              ...      ...     ...
# 1015   1015       Motorola Moto Edge S30 Pro  ₹34,990    83.0
# 1016   1016                      Honor X8 5G  ₹14,990    75.0
# 1017   1017  POCO X4 GT 5G (8GB RAM + 256GB)  ₹28,990    85.0
# 1018   1018             Motorola Moto G91 5G  ₹19,990    80.0
# 1019   1019           Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                                     sim  \
# 0               Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
# First of all ya index aya kaha se # battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,756,
# 759,764,819,855,859,884,915,916,927,929,932,990,1002))  

# Same h bas +2 Kia hua h index m

dx[~dx["battery"].str.contains("Battery")].index
# Out:
# Index([ 111,  149,  307,  363,  376,  439,  448,  551,  582,  608,  611,  628,
#         640,  645,  647,  657,  665,  699,  748,  754,  757,  762,  817,  853,
#         857,  882,  913,  914,  925,  927,  930,  988, 1000],
#       dtype='int64')

# %%
# battery_rows = set((113,151,309,365,378,441,450,553,584,610,613,630,642,647,649,659,667,701,
# 750,756,759,764,819,855,859,884,915,916,927,929,932,990,1002))

df1[df1["index"].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 306    309       Apple iPhone 12 (128GB)   55999    75.0
# 362    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 375    378               Nokia 2660 Flip    4649     NaN
# 437    441        Apple iPhone SE 3 2022   43900     NaN
# 446    450           Apple iPhone 15 Pro  130990    75.0
# 615    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 734    756    Apple iPod Touch (7th Gen)   18900     NaN
# 741    764             Apple iPhone SE 4   49990    60.0
# 828    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 885    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 886    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# Drop the 375 index

df1.drop(375,inplace=True)

# %%
df2 = df1[df1["index"].isin(battery_rows)]

# %%
df2
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 306    309       Apple iPhone 12 (128GB)   55999    75.0
# 362    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 437    441        Apple iPhone SE 3 2022   43900     NaN
# 446    450           Apple iPhone 15 Pro  130990    75.0
# 615    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 734    756    Apple iPod Touch (7th Gen)   18900     NaN
# 741    764             Apple iPhone SE 4   49990    60.0
# 828    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 885    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 886    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# Here we need to shift the data after the 7th colmn

df2.iloc[:,7:].shift(1,axis = 1)
# Out:
#     battery                                            display  \
# 111    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 149    None                 5.4 inches, 1080 x 2340 px Display
# 306    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 362    None                 5.4 inches, 1080 x 2340 px Display
# 437    None                  4.7 inches, 750 x 1334 px Display
# 446    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 615    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 734    None                    8 MP Rear & 1.2 MP Front Camera
# 741    None                  6.1 inches, 750 x 1580 px Display
# 828    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 885    None                 5.4 inches, 1080 x 2340 px Display
# 886    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 camera  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# ...

# %%
# Imortaint steps :-----------  To shift the data threw column-------

#Be carefull

# %%
# Step 1 :- value nikalo
df2.iloc[:,7:].shift(1,axis = 1).values
# Out:
# array([[None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '4.7 inches, 750\u2009x\u20091334\u2009px Display',
#         '12\u2009MP Rear & 7\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
# ...

# %%
# Step 2 :-value ko store kro
x = df2.iloc[:,7:].shift(1,axis = 1).values

# %%
# Step 3 :- index nikal ka value update kro
df1.loc[df2.index , df2.columns[7:]] = x
#         Index      Index column       Values update

# %%
df1[df1["index"].isin(battery_rows)]
# Out:
#      index                         model   price  rating  \
# 111    113               Apple iPhone 12   51999    74.0
# 149    151          Apple iPhone 12 Mini   40999    74.0
# 306    309       Apple iPhone 12 (128GB)   55999    75.0
# 362    365  Apple iPhone 12 Mini (128GB)   45999    75.0
# 437    441        Apple iPhone SE 3 2022   43900     NaN
# 446    450           Apple iPhone 15 Pro  130990    75.0
# 615    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 734    756    Apple iPod Touch (7th Gen)   18900     NaN
# 741    764             Apple iPhone SE 4   49990    60.0
# 828    855   Apple iPhone 12 Pro (256GB)  119900    80.0
# 885    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 886    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 306  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# display_rows = set((378,441,450,553,584,610,613,630,642,647,649,659,667,701,750,759,764,819,859,884,915,916,927,929,932,990,1002))

df1[df1["index"].isin(display_rows)]
# Out:
#      index                         model   price  rating  \
# 437    441        Apple iPhone SE 3 2022   43900     NaN
# 446    450           Apple iPhone 15 Pro  130990    75.0
# 615    630   Apple iPhone 12 Pro (512GB)  139900    80.0
# 741    764             Apple iPhone SE 4   49990    60.0
# 885    915  Apple iPhone 12 Mini (256GB)   55999    75.0
# 886    916       Apple iPhone 12 (256GB)   67999    76.0
#
#                                          sim  \
# 437  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 446  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 615  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 741  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 885  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 886  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 437  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 446                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# ...

# %%
# display_rows lools perfect no need of cleaning

# %%
# camera_rows = set((100,113,151,157,161,238,273,308,309,323,324,365,367,378,394,441,450,484,506,
# 534,553,571,572,575,584,610,613,615,630,642,647,649,659,667,684,687,705,711,723,728,750,756,759,
# 764,792,819,846,854,855,858,883,884,896,915,916,927,929,932,945,956,990,995,1002,1016 ))


df1[df1["index"].isin(camera_rows)]
# Out:
#      index                                     model   price  rating  \
# 98     100                            Vivo X Fold 5G  106990     NaN
# 111    113                           Apple iPhone 12   51999    74.0
# 149    151                      Apple iPhone 12 Mini   40999    74.0
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 306    309                   Apple iPhone 12 (128GB)   55999    75.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 362    365              Apple iPhone 12 Mini (128GB)   45999    75.0
# 364    367                          OPPO Find N Flip   89990    88.0
# ...

# %%
# 98 , 155 , 159 ,

# %%
tem = df1[~df1["camera"].str.contains("MP")]

# %%
tem
# Out:
#      index                                     model   price  rating  \
# 69      71                          Oppo Find N Fold   99990     NaN
# 98     100                            Vivo X Fold 5G  106990     NaN
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 364    367                          OPPO Find N Flip   89990    88.0
# 391    394                         OPPO Find N2 Flip   70990    88.0
# 478    484                          Vivo X Fold Plus  113990     NaN
# 500    506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# ...

# %%
tem1 = tem[tem["card"].str.contains("MP")]

# %%
tem1
# Out:
#      index                                     model   price  rating  \
# 69      71                          Oppo Find N Fold   99990     NaN
# 98     100                            Vivo X Fold 5G  106990     NaN
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 364    367                          OPPO Find N Flip   89990    88.0
# 391    394                         OPPO Find N2 Flip   70990    88.0
# 478    484                          Vivo X Fold Plus  113990     NaN
# 500    506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# ...

# %%
#====

# %%
y=tem1.iloc[:,9:].shift(-1,axis = 1).values

# %%
y
# Out:
# array([['64\u2009MP + 10\u2009MP + 8\u2009MP Triple Rear & 32\u2009MP Front Camera',
#         'Android v12', None],
#        ['50\u2009MP Quad Rear & 16\u2009MP Front Camera', 'Android v12',
#         None],
#        ['5\u2009MP Rear Camera',
#         'Memory Card Supported, upto 32\u2009GB', None],
#        ['50\u2009MP + 48\u2009MP + 32\u2009MP Triple Rear & 32\u2009MP + 32\u2009MP Dual Front Camera',
#         'Memory Card Not Supported', None],
#        ['50\u2009MP + 13\u2009MP + 8\u2009MP Triple Rear & 20\u2009MP Front Camera',
#         'Android v12', None],
#        ['2\u2009MP Rear Camera', 'Memory Card Supported', None],
#        ['12\u2009MP + 12\u2009MP Dual Rear & 10\u2009MP Front Camera',
#         'Memory Card Not Supported', None],
#        ['50\u2009MP + 12\u2009MP + 10\u2009MP Triple Rear & 10\u2009MP + 4\u2009MP Dual Front Camera',
#         'Android v12', None],
#        ['64\u2009MP + 16\u2009MP + 8\u2009MP Triple Rear & 32\u2009MP Front Camera',
# ...

# %%
tem.loc[tem1.index , tem1.columns[9:]] = y

# %%
tem
# Out:
#      index                                     model   price  rating  \
# 69      71                          Oppo Find N Fold   99990     NaN
# 98     100                            Vivo X Fold 5G  106990     NaN
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 364    367                          OPPO Find N Flip   89990    88.0
# 391    394                         OPPO Find N2 Flip   70990    88.0
# 478    484                          Vivo X Fold Plus  113990     NaN
# 500    506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# ...

# %%
tem[~tem["camera"].str.contains("MP")]
# Out:
#      index                       model  price  rating    sim      processor  \
# 734    756  Apple iPod Touch (7th Gen)  18900     NaN  Wi-Fi  32 GB inbuilt
#
#                                  ram battery                          display  \
# 734  4 inches, 640 x 1136 px Display    None  8 MP Rear & 1.2 MP Front Camera
#
#       camera         card         os
# 734  iOS v12  No FM Radio  Bluetooth

# %%
temp3=tem[~tem["camera"].str.contains("MP")]

# %%
zz = temp3.iloc[:,9:].shift(1,axis = 1)

# %%
tem.loc[temp3.index , temp3.columns[9:]] = zz

# %%
tem
# Out:
#      index                                     model   price  rating  \
# 69      71                          Oppo Find N Fold   99990     NaN
# 98     100                            Vivo X Fold 5G  106990     NaN
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 364    367                          OPPO Find N Flip   89990    88.0
# 391    394                         OPPO Find N2 Flip   70990    88.0
# 478    484                          Vivo X Fold Plus  113990     NaN
# 500    506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# ...

# %%
#   69,98,235,320,478,562,684,690,769,909,920,978

temx = tem.loc[[69,98,235,320,478,562,684,690,769,909,920,978]]

# %%
temx1 = temx.iloc[:,10:].shift(1,axis = 1)

# %%
tem.loc[temx.index , temx.columns[9:]] = temx1

# %%
tem
# Out:
#      index                                     model   price  rating  \
# 69      71                          Oppo Find N Fold   99990     NaN
# 98     100                            Vivo X Fold 5G  106990     NaN
# 155    157                           Nokia 2780 Flip    4990     NaN
# 159    161                           Oppo Find N2 5G   94990     NaN
# 235    238                      Xiaomi Mix Fold 2 5G  106990     NaN
# 270    273                         Nokia 2720 V Flip    6199     NaN
# 305    308                   Samsung Galaxy Z Flip 3   69999    84.0
# 320    323                   Samsung Galaxy Z Fold 4  154998     NaN
# 321    324                          Royole FlexPai 2  109999    87.0
# 364    367                          OPPO Find N Flip   89990    88.0
# 391    394                         OPPO Find N2 Flip   70990    88.0
# 478    484                          Vivo X Fold Plus  113990     NaN
# 500    506                Samsung Galaxy Z Flip 4 5G   89999    88.0
# ...

# %%
print(tem.index)
# Out:
# Index([ 69,  98, 155, 159, 235, 270, 305, 320, 321, 364, 391, 478, 500, 562,
#        563, 601, 665, 684, 690, 702, 707, 734, 769, 821, 867, 909, 920, 958,
#        978],
#       dtype='int64')

# %%
df1.iloc[tem.index]=tem.values

# %%
df1
# Out:
#      index                            model   price  rating  \
# 0        2                    OnePlus 11 5G   54999    89.0
# 1        3        OnePlus Nord CE 2 Lite 5G   19989    81.0
# 2        4            Samsung Galaxy A14 5G   16499    75.0
# 3        5             Motorola Moto G62 5G   14999    81.0
# 4        6               Realme 10 Pro Plus   24999    82.0
# ..     ...                              ...     ...     ...
# 979   1017       Motorola Moto Edge S30 Pro   34990    83.0
# 980   1018                      Honor X8 5G   14990    75.0
# 981   1019  POCO X4 GT 5G (8GB RAM + 256GB)   28990    85.0
# 982   1016                    Vivo X Fold 2  119990     NaN
# 983   1021           Samsung Galaxy M52s 5G   24990    74.0
#
#                                                    sim  \
# 0              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df1.fillna("No Information",inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14244\1188051088.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'No Information' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df1.fillna("No Information",inplace=True)

# %%
# Check error again
df1[df1["index"].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#      index                                     model   price          rating  \
# 98     100                            Vivo X Fold 5G  106990  No Information
# 111    113                           Apple iPhone 12   51999            74.0
# 149    151                      Apple iPhone 12 Mini   40999            74.0
# 155    157                           Nokia 2780 Flip    4990  No Information
# 159    161                           Oppo Find N2 5G   94990  No Information
# 235    238                      Xiaomi Mix Fold 2 5G  106990  No Information
# 270    273                         Nokia 2720 V Flip    6199  No Information
# 305    308                   Samsung Galaxy Z Flip 3   69999            84.0
# 306    309                   Apple iPhone 12 (128GB)   55999            75.0
# 320    323                   Samsung Galaxy Z Fold 4  154998  No Information
# 321    324                          Royole FlexPai 2  109999            87.0
# ...

# %%
# Shifting 

ind =  df1[df1["card"].str.contains("MP")].index

# %%
ind
# Out:
# Index([391, 478, 500, 562, 601, 665, 684, 690, 702, 707, 769, 821, 867, 909,
#        920, 958, 978],
#       dtype='int64')

# %%
df1.loc[ind, df1.columns[9:]] = df1.loc[ind, df1.columns[9:]].shift(-1, axis=1)

# %%
# For Shifting android to OS

#  df1.loc[ind, df1.columns[110:]] = df1.loc[df1[df1["card"].str.contains("Android")].index, df1.columns[10:]].shift(1, axis=1)

# %%
mask = df1["card"].str.contains("Android", case=False, na=False)

cols_to_shift = df1.columns[10:]   # after 10th column

df1.loc[mask, cols_to_shift] = df1.loc[mask, cols_to_shift].shift(1, axis=1)

# %%
df1.head(10)
# Out:
#    index                                    model  price rating  \
# 0      2                            OnePlus 11 5G  54999   89.0
# 1      3                OnePlus Nord CE 2 Lite 5G  19989   81.0
# 2      4                    Samsung Galaxy A14 5G  16499   75.0
# 3      5                     Motorola Moto G62 5G  14999   81.0
# 4      6                       Realme 10 Pro Plus  24999   82.0
# 5      7  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999   80.0
# 6      8                          Apple iPhone 14  65999   81.0
# 7      9            Xiaomi Redmi Note 12 Pro Plus  29999   86.0
# 8     10                          Nothing Phone 1  26749   85.0
# 9     11                       OnePlus Nord 2T 5G  28999   84.0
#
#                                               sim  \
# 0         Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# ...

# %%
df1[df1["card"].str.contains("iOS", case=False, na=False)]
# Out:
#      index                       model  price          rating  \
# 597    609             Apple iPhone 7s  52990  No Information
# 641    658        Apple iPhone SE 2020  39900            63.0
# 736    756  Apple iPod Touch (7th Gen)  18900  No Information
#
#                                      sim  \
# 597     Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 641  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 736                                Wi-Fi
#
#                                          processor  \
# 597  Fusion APL1024, Quad Core, 2.37 GHz Processor
# 641      A13 Bionic, Hexa Core, 2.65 GHz Processor
# 736                                  32 GB inbuilt
#
#                                  ram                                  battery  \
# 597          3 GB RAM, 32 GB inbuilt                         2230 mAh Battery
# 641          3 GB RAM, 64 GB inbuilt  1821 mAh Battery with 18W Fast Charging
# 736  4 inches, 640 x 1136 px Display                           No Information
#
# ...

# %%
mask2 = df1["card"].str.contains("iOS", case=False, na=False)

cols_to_shift2 = df1.columns[10:]   # after 10th column

df1.loc[mask2, cols_to_shift2] = df1.loc[mask2, cols_to_shift2].shift(1, axis=1)

# %%
df1[df1["card"].str.contains("iOS", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [index, model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %%
df1[df1["card"].str.contains("Android", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [index, model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %%
df1
# Out:
#      index                            model   price          rating  \
# 0        2                    OnePlus 11 5G   54999            89.0
# 1        3        OnePlus Nord CE 2 Lite 5G   19989            81.0
# 2        4            Samsung Galaxy A14 5G   16499            75.0
# 3        5             Motorola Moto G62 5G   14999            81.0
# 4        6               Realme 10 Pro Plus   24999            82.0
# ..     ...                              ...     ...             ...
# 979   1017       Motorola Moto Edge S30 Pro   34990            83.0
# 980   1018                      Honor X8 5G   14990            75.0
# 981   1019  POCO X4 GT 5G (8GB RAM + 256GB)   28990            85.0
# 982   1016                    Vivo X Fold 2  119990  No Information
# 983   1021           Samsung Galaxy M52s 5G   24990            74.0
#
#                                                    sim  \
# 0              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ...

# %%
# Check error again
df1[df1["index"].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#      index                                     model   price          rating  \
# 98     100                            Vivo X Fold 5G  106990  No Information
# 111    113                           Apple iPhone 12   51999            74.0
# 149    151                      Apple iPhone 12 Mini   40999            74.0
# 155    157                           Nokia 2780 Flip    4990  No Information
# 159    161                           Oppo Find N2 5G   94990  No Information
# 235    238                      Xiaomi Mix Fold 2 5G  106990  No Information
# 270    273                         Nokia 2720 V Flip    6199  No Information
# 305    308                   Samsung Galaxy Z Flip 3   69999            84.0
# 306    309                   Apple iPhone 12 (128GB)   55999            75.0
# 320    323                   Samsung Galaxy Z Fold 4  154998  No Information
# 321    324                          Royole FlexPai 2  109999            87.0
# ...

# %%
mask2 = df1["camera"].str.contains("iOS", case=False, na=False)

cols_to_shift2 = df1.columns[8:]   # after 10th column

df1.loc[mask2, cols_to_shift2] = df1.loc[mask2, cols_to_shift2].shift(2, axis=1)

# %%
df1[df1["camera"].str.contains("iOS", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [index, model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %%
df1[df1["card"].isnull()]
# Out:
# Empty DataFrame
# Columns: [index, model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %%
df1.isnull().sum()
# Out:
# index          0
# model          0
# price          0
# rating         0
# sim            0
# processor      0
# ram            0
# battery        0
# display        1
# camera         1
# card         216
# os             9
# dtype: int64

# %%
df1.fillna("Information Unavailable",inplace=True)

# %%
df1.isnull().sum()
# Out:
# index        0
# model        0
# price        0
# rating       0
# sim          0
# processor    0
# ram          0
# battery      0
# display      0
# camera       0
# card         0
# os           0
# dtype: int64

# %%
# Lets break the columns : ----

# %%
dfz = pd.DataFrame(data = df1["model"])

# %%
dfz
# Out:
#                                model
# 0                      OnePlus 11 5G
# 1          OnePlus Nord CE 2 Lite 5G
# 2              Samsung Galaxy A14 5G
# 3               Motorola Moto G62 5G
# 4                 Realme 10 Pro Plus
# ..                               ...
# 979       Motorola Moto Edge S30 Pro
# 980                      Honor X8 5G
# 981  POCO X4 GT 5G (8GB RAM + 256GB)
# 982                    Vivo X Fold 2
# 983           Samsung Galaxy M52s 5G
#
# [980 rows x 1 columns]

# %%
dfz["model"].str.split().str.len().max()
# Out:
# 11

# %%
dfz["Company"] = dfz["model"].str.split().str[0]

# %%
dfz
# Out:
#                                model   Company
# 0                      OnePlus 11 5G   OnePlus
# 1          OnePlus Nord CE 2 Lite 5G   OnePlus
# 2              Samsung Galaxy A14 5G   Samsung
# 3               Motorola Moto G62 5G  Motorola
# 4                 Realme 10 Pro Plus    Realme
# ..                               ...       ...
# 979       Motorola Moto Edge S30 Pro  Motorola
# 980                      Honor X8 5G     Honor
# 981  POCO X4 GT 5G (8GB RAM + 256GB)      POCO
# 982                    Vivo X Fold 2      Vivo
# 983           Samsung Galaxy M52s 5G   Samsung
#
# [980 rows x 2 columns]

# %%
dfz["sim"] = df1["sim"]

# %%
dfz["Dual Sim"] = dfz["sim"].str.split(",").str[0]

# %%
dfz["3G"] = dfz["sim"].str.split(",").str[1]

# %%
dfz["4G"] = dfz["sim"].str.split(",").str[2]

# %%
dfz["5G"] = dfz["sim"].str.split(",").str[3]

# %%
dfz["VoLTE"] = dfz["sim"].str.split(",").str[4]

# %%
dfz["Wi-Fi"] = dfz["sim"].str.split(",").str[5]

# %%
dfz["NFC"] = dfz["sim"].str.split(",").str[6]

# %%
dfz["IR Blaster"] = dfz["sim"].str.split(",").str[7]

# %%
dfz
# Out:
#                                model   Company  \
# 0                      OnePlus 11 5G   OnePlus
# 1          OnePlus Nord CE 2 Lite 5G   OnePlus
# 2              Samsung Galaxy A14 5G   Samsung
# 3               Motorola Moto G62 5G  Motorola
# 4                 Realme 10 Pro Plus    Realme
# ..                               ...       ...
# 979       Motorola Moto Edge S30 Pro  Motorola
# 980                      Honor X8 5G     Honor
# 981  POCO X4 GT 5G (8GB RAM + 256GB)      POCO
# 982                    Vivo X Fold 2      Vivo
# 983           Samsung Galaxy M52s 5G   Samsung
#
#                                                    sim  Dual Sim   3G   4G  \
# 0              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC  Dual Sim   3G   4G
# 1                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi  Dual Sim   3G   4G
# 2                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi  Dual Sim   3G   4G
# 3                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi  Dual Sim   3G   4G
# ...

# %%
dfz.drop("sim",axis=1,inplace=True)

# %%
dfz["processor"] = df1["processor"]

# %%
dfz
# Out:
#                                model   Company  Dual Sim   3G   4G   5G  \
# 0                      OnePlus 11 5G   OnePlus  Dual Sim   3G   4G   5G
# 1          OnePlus Nord CE 2 Lite 5G   OnePlus  Dual Sim   3G   4G   5G
# 2              Samsung Galaxy A14 5G   Samsung  Dual Sim   3G   4G   5G
# 3               Motorola Moto G62 5G  Motorola  Dual Sim   3G   4G   5G
# 4                 Realme 10 Pro Plus    Realme  Dual Sim   3G   4G   5G
# ..                               ...       ...       ...  ...  ...  ...
# 979       Motorola Moto Edge S30 Pro  Motorola  Dual Sim   3G   4G   5G
# 980                      Honor X8 5G     Honor  Dual Sim   3G   4G   5G
# 981  POCO X4 GT 5G (8GB RAM + 256GB)      POCO  Dual Sim   3G   4G   5G
# 982                    Vivo X Fold 2      Vivo  Dual Sim   3G   4G   5G
# 983           Samsung Galaxy M52s 5G   Samsung  Dual Sim   3G   4G   5G
#
#       VoLTE   Wi-Fi   NFC   IR Blaster  \
# 0     VoLTE   Wi-Fi   NFC          NaN
# ...

# %%
dfz["Processor_Name"] = dfz["processor"].str.split(",").str[0]

# %%
dfz["Processor_Core"] = dfz["processor"].str.split(",").str[1]

# %%
dfz["Processor_GHz"] = dfz["processor"].str.split(",").str[2]

# %%
dfz.drop("processor",axis=1,inplace=True)

# %%
dfz["ram"]=df1["ram"]

# %%
dfz["RAM"] = dfz["ram"].str.split(",").str[0]

# %%
dfz["Storage"] = dfz["ram"].str.split(",").str[1]

# %%
dfz.drop("ram",axis=1,inplace=True)

# %%
dfz["battery"]=df1["battery"]

# %%
dfz["mAh"] = dfz["battery"].str.split().str[0:2].str.join(" ")

# %%
dfz["Watt"] = dfz["battery"].str.split().str[4]

# %%
dfz.drop("battery",axis=1,inplace=True)

# %%
dfz["display"]=df1["display"]

# %%
dfz["Display_size"]=dfz["display"].str.split(",").str[0]

# %%
dfz["Display_px"]=dfz["display"].str.split(",").str[1]

# %%
dfz["Display_Hz"]=dfz["display"].str.split(",").str[2]

# %%
dfz.drop("display",axis=1,inplace=True)

# %%
dfz["camera"]=df1["camera"]

# %%
dfz["Back_camera"]=dfz["camera"].str.split("&").str[0]

# %%
dfz["Front_camera"]=dfz["camera"].str.split("&").str[1]

# %%
dfz.drop("camera",axis=1,inplace=True)

# %%
dfz["card"]=df1["card"]

# %%
dfz["Memory_card"] = dfz["card"].str.split(",").str[0]

# %%
dfz["Memory_card_TB"] = dfz["card"].str.split(",").str[1]

# %%
dfz.drop("card",axis=1,inplace=True)

# %%
dfz.insert(0,"index",df1["index"])

# %%
dfz.insert(1,"price",df1["price"])

# %%
dfz.insert(2,"rating",df1["rating"])

# %%
dfz["OS"] = df1["os"]

# %% [markdown]
# # This our final cleaned data :--

# %%
dfz
# Out:
#      index   price          rating                            model   Company  \
# 0        2   54999            89.0                    OnePlus 11 5G   OnePlus
# 1        3   19989            81.0        OnePlus Nord CE 2 Lite 5G   OnePlus
# 2        4   16499            75.0            Samsung Galaxy A14 5G   Samsung
# 3        5   14999            81.0             Motorola Moto G62 5G  Motorola
# 4        6   24999            82.0               Realme 10 Pro Plus    Realme
# ..     ...     ...             ...                              ...       ...
# 979   1017   34990            83.0       Motorola Moto Edge S30 Pro  Motorola
# 980   1018   14990            75.0                      Honor X8 5G     Honor
# 981   1019   28990            85.0  POCO X4 GT 5G (8GB RAM + 256GB)      POCO
# 982   1016  119990  No Information                    Vivo X Fold 2      Vivo
# 983   1021   24990            74.0           Samsung Galaxy M52s 5G   Samsung
#
# ...

# %%
dfz.to_csv("Smartphone_output.csv", index=False)
